# %%
# Write a Python program to find duplicate values from a list and display those.

input_list = [1, 2, 3, 4, 5, 6, 3, 2, 7, 8, 9, 1]
duplicates = []
for item in input_list:
    if input_list.count(item) > 1 and item not in duplicates:
        duplicates.append(item)
print("Duplicate values are:", duplicates)
# Out:
# Duplicate values are: [1, 2, 3]
