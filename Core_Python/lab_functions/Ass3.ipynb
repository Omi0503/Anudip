# %%
import random

rand_num_list = []

for _ in range(5):
    rand_num_list.append(random.randint(1, 100))

print(rand_num_list)

print(max(rand_num_list))

print( min(rand_num_list))
# Out:
# [19, 59, 43, 2, 70]
# 70
# 2

# %%
max(rand_num_list)
# Out:
# 59

# %%
min(rand_num_list)
# Out:
# 3
