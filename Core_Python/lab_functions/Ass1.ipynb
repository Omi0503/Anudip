# %%
def div(a,b):
    if b==0:
        print("Divison is not possibal")
    else:
        return a/b
a=int(input("Enter number:"))
b=int(input("Enter number:"))
div(a,b)
# Out:
# Enter number: 10
# Enter number: 2
# 5.0
