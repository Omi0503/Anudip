# %%
#Ass1

#declare tuple
tuplex = (2, 4, 5, 6, 2, 3, 4, 4, 7)
#count the number 4
count_4 = tuplex.count(4)
#print number
print("The number 4 appears", count_4, "times.")
# Out:
# The number 4 appears 3 times.

# %%
#Ass2

#Declare list
listx = [5, 10, 7, 4, 15, 3]
#Converting list into tuple and Printing
print(tuple(listx))
# Out:
# (5, 10, 7, 4, 15, 3)

# %%
#Ass3

#Declare list of tuple
tuples_list = [(1, 2), (3, 4), (5, 6)]
#Calculate sum numbers
sum_of_numbers = sum(sum(tup) for tup in tuples_list)
#Printing sum of number
print("The sum of the numbers in the tuple is:", sum_of_numbers)
# Out:
# The sum of the numbers in the tuple is: 21

# %%
#Ass4

#Declare tuple's
employee1 = ("John Doe", 101, "Human Resources", 60000)
employee2 = ("Alice Smith", 102, "Marketing", 55000)
employee3 = ("Bob Johnson", 103, "Engineering", 75000)

# Store all employee data in a list
employees = [employee1, employee2, employee3]

# Iterate over each employee tuple in the list
for employee in employees:
    name, emp_id, department, salary = employee
    #Print employee details
    print(f"Name: {name}, ID: {emp_id}, Department: {department}, Salary: ${salary}")
# Out:
# Name: John Doe, ID: 101, Department: Human Resources, Salary: $60000
# Name: Alice Smith, ID: 102, Department: Marketing, Salary: $55000
# Name: Bob Johnson, ID: 103, Department: Engineering, Salary: $75000

# %%
#Ass1

#declare tuple
tuplex = (2, 4, 5, 6, 2, 3, 4, 4, 7)
#count the number 4
count_4 = tuplex.count(4)
#print number
print("The number 4 appears", count_4, "times.")

'''----------------------------

Output:

The number 4 appears 3 times.

=================================='''

#Ass2

#Declare list
listx = [5, 10, 7, 4, 15, 3]
#Converting list into tuple and Printing
print(tuple(listx))

'''---------------------------------

Output:

(5, 10, 7, 4, 15, 3)

========================================'''

#Ass3

#Declare list of tuple
tuples_list = [(1, 2), (3, 4), (5, 6)]
#Calculate sum numbers
sum_of_numbers = sum(sum(tup) for tup in tuples_list)
#Printing sum of number
print("The sum of the numbers in the tuple is:", sum_of_numbers)

'''----------------------------------------

Output:

The sum of the numbers in the tuple is: 21

===================================================='''

#Ass4

#Declare tuple's
employee1 = ("John Doe", 101, "Human Resources", 60000)
employee2 = ("Alice Smith", 102, "Marketing", 55000)
employee3 = ("Bob Johnson", 103, "Engineering", 75000)

# Store all employee data in a list
employees = [employee1, employee2, employee3]

# Iterate over each employee tuple in the list
for employee in employees:
    name, emp_id, department, salary = employee
    #Print employee details
    print(f"Name: {name}, ID: {emp_id}, Department: {department}, Salary: ${salary}")

'''-------------------------------------------

Output:

Name: John Doe, ID: 101, Department: Human Resources, Salary: $60000
Name: Alice Smith, ID: 102, Department: Marketing, Salary: $55000
Name: Bob Johnson, ID: 103, Department: Engineering, Salary: $75000	'''
# Out:
# The number 4 appears 3 times.
# (5, 10, 7, 4, 15, 3)
# The sum of the numbers in the tuple is: 21
# Name: John Doe, ID: 101, Department: Human Resources, Salary: $60000
# Name: Alice Smith, ID: 102, Department: Marketing, Salary: $55000
# Name: Bob Johnson, ID: 103, Department: Engineering, Salary: $75000
# '-------------------------------------------\n\nOutput:\n\nName: John Doe, ID: 101, Department: Human Resources, Salary: $60000\nName: Alice Smith, ID: 102, Department: Marketing, Salary: $55000\nName: Bob Johnson, ID: 103, Department: Engineering, Salary: $75000\t'
